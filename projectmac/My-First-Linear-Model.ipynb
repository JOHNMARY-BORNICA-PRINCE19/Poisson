# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([3, 5, 7, 9,11])


y = np.array([ 11, 16, 21, 26,31 ])

# %%
plt.plot(x, y, 'o')
plt.title("My First Linear Model")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')
